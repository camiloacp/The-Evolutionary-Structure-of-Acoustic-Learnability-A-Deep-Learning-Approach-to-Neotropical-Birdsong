# %%
import os
import pandas as pd
import numpy as np 
import seaborn as sns
from tqdm import tqdm
import pickle

from pydub import AudioSegment
from IPython.display import Audio

import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, accuracy_score
import itertools

import warnings
warnings.filterwarnings("ignore")
# Out:
# /var/cache/pypoetry/virtualenvs/app-We1gMlF5-py3.10/lib/python3.10/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
# creating the dataframe which has path to wav file and it's label

df = pd.read_csv('./data/chunks.csv')
df = df[['audio_path', 'label']]
print(df.shape)
# Out:
# (60674, 2)

# %%
etiquetas = df['label']
clases, conteo_clases = np.unique(etiquetas, return_counts=True)
weight = dict(zip(clases, np.max(conteo_clases) / conteo_clases))
weight
# Out:
# {0: 2.8002004259050484, 1: 1.0}

# %%
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)

for train_index, test_index in sss.split(df['audio_path'], df['label']):
    df_train = df.iloc[train_index]
    df_test = df.iloc[test_index]

# %%
X = df_train['audio_path']
y = df_train['label']

X_test = df_test['audio_path']
y_test = df_test['label']

# %%
num_clases = y.nunique()

# %%
#getting mfcc features for all the data points in test and train

def get_spec(path):
    y, sr = librosa.load(path, sr=None, mono=True)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=10000)
    return S

# %%
def process_audio_files(X, y):
    """
    Processes a list of audio file paths to extract MFCC features and resize them.

    Args:
        X (pd.Series): A pandas Series containing paths to audio files.
        y (pd.Series): A pandas Series containing labels corresponding to the audio files.

    Returns:
        tuple: A tuple containing:
            - X_processed (np.ndarray): A numpy array of processed MFCC features with shape (num_files, 65, 40).
            - y_processed (np.ndarray): A numpy array of labels corresponding to the audio files.
    """
    temp = []
    label = []

    for i in tqdm(range(len(X))):
        audio_path = X.iloc[i]
        spec = get_spec(audio_path)
        spec = np.resize(spec, (65, 40,))
        temp.append(spec)
        label.append(y.iloc[i])

    X_processed = np.asarray(temp)
    y_processed = np.asarray(label)

    return X_processed, y_processed

# %%
# %%time

# X_processed, y = process_audio_files(X, y)
# X_test_processed, y_test = process_audio_files(X_test, y_test)
# Out:
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 10.5 µs

# %%
# with open('X_processed_spec.pkl', 'wb') as f:
#     pickle.dump(X_processed, f)
    
# with open('y_train_spec.pkl', 'wb') as f:
#     pickle.dump(y, f)

# with open('X_test_processed_spec.pkl', 'wb') as f:
#     pickle.dump(X_test_processed, f)
    
# with open('y_test_spec.pkl', 'wb') as f:
#     pickle.dump(y_test, f)

# %%
with open('X_processed_spec.pkl', 'rb') as f:
    X_processed = pickle.load(f)

with open('y_train_spec.pkl', 'rb') as f:
    y = pickle.load(f)

with open('X_test_processed_spec.pkl', 'rb') as f:
    X_test_processed = pickle.load(f)
    
with open('y_test_spec.pkl', 'rb') as f:
    y_test = pickle.load(f)

# %%
print(f'El conjunto de entrenamiento tiene la forma {X_processed.shape}')
print(f'Los labels del conjunto de entrenamiento tiene la forma {y.shape}')
# Out:
# El conjunto de entrenamiento tiene la forma (42471, 65, 40)
# Los labels del conjunto de entrenamiento tiene la forma (42471,)

# %% [markdown]
# #### Modelling

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
import keras.backend as K

tf.keras.backend.clear_session()
# Out:
# 2024-10-14 20:49:02.323508: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-14 20:49:02.346191: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-14 20:49:02.353186: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-14 20:49:02.370572: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728953350.354998   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728953350.410319   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728953350.410639   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Add attention layer to the deep learning network
class Attention(layers.Layer):
    """
    Custom Keras Layer implementing an Attention mechanism.

    Methods
    -------
    build(input_shape)
        Initializes the weights and biases for the attention mechanism.
    
    call(x)
        Applies the attention mechanism to the input tensor `x` and returns the context vector.

    Parameters
    ----------
    input_shape : tuple
        Shape of the input tensor.
    
    x : tensor
        Input tensor to which the attention mechanism is applied.

    Returns
    -------
    tensor
        Context vector obtained after applying the attention mechanism.
    """
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name='attention_weight', shape=(input_shape[-1], 1), 
                                 initializer='random_normal', trainable=True)
        self.b = self.add_weight(name='attention_bias', shape=(input_shape[1], 1), 
                                 initializer='zeros', trainable=True)
        super(Attention, self).build(input_shape)

    def call(self, x):
        # Alignment scores. Pass them through tanh function
        e = tf.tanh(tf.matmul(x, self.W) + self.b)  # Cambiado K.dot por tf.matmul
        # Remove dimension of size 1
        e = tf.squeeze(e, axis=-1)  # Cambiado K.squeeze por tf.squeeze
        # Compute the weights
        alpha = tf.nn.softmax(e)  # Cambiado K.softmax por tf.nn.softmax
        # Reshape to tensorFlow format
        alpha = tf.expand_dims(alpha, axis=-1)  # Cambiado K.expand_dims por tf.expand_dims
        # Compute the context vector
        context = x * alpha
        context = tf.reduce_sum(context, axis=1)  # Cambiado K.sum por tf.reduce_sum
        return context

# %%
#Create model

#input
input = layers.Input(shape=(65,40), name='input_layer')

#cnn
x = layers.Conv1D(256, (3,), activation='relu')(input)
x = layers.BatchNormalization()(x)
x = layers.Conv1D(128, (3,), activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv1D(64, (3,), activation='relu')(x)
x = layers.BatchNormalization()(x)
#lstm
x = layers.LSTM(256, return_sequences = True)(x)
x = layers.Dropout(0.5)(x)
x = layers.LSTM(128, return_sequences = True)(x)
x = layers.Dropout(0.5)(x)
x = layers.LSTM(64, return_sequences = True)(x)
x = layers.Dropout(0.5)(x)
x = Attention()(x)
#dense
x = layers.Dense(256,'relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128,'relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(64,'relu')(x)
x = layers.Dropout(0.5)(x)

#output
output = layers.Dense(num_clases, activation='softmax', name='output_layer')(x)

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# I0000 00:00:1728953350.460588   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728953350.460912   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728953350.461158   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728953350.623525   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728953350.623824   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728953350.624086   23284 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-14 20:49:10.624257: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14787 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 65, 40)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 63, 256)        │        30,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 63, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 61, 128)        │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 61, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 59, 64)         │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 59, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 59, 256)        │       328,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 59, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 59, 128)        │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 59, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 59, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 59, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention (Attention)           │ (None, 64)             │           123 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        16,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 789,117 (3.01 MB)
#  Trainable params: 788,221 (3.01 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    'model_weights_spec.weights.h5',  
    monitor='val_loss',
    mode='min',
    verbose=1,
    save_weights_only=True,  # guardar solo los pesos
    save_best_only=True,     # guardar solo el mejor modelo
)

# Callback para TensorBoard
tensorboard_cb = tf.keras.callbacks.TensorBoard(
    log_dir='logs',
    histogram_freq=1
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.1, 
    patience=10, 
    min_lr=0.00001)

# Callback para EarlyStopping
early_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=50,
    mode='min'
)

callbacks = [checkpoint_cb, tensorboard_cb, early_callback, reduce_lr]

# %%
#compile
ls = tf.keras.losses.SparseCategoricalCrossentropy()
adam = tf.keras.optimizers.Adam()
model.compile(adam, ls, metrics=['accuracy'])

#fitting
sss = StratifiedShuffleSplit(n_splits=5, test_size=0.3, random_state=42)

for train_index, val_index in sss.split(np.zeros(X_processed.shape[0]), y):
    X_train, X_val = X_processed[train_index], X_processed[val_index]
    y_train_split, y_val = y[train_index], y[val_index] 

    # Entrenamiento del modelo
    history = model.fit(
        X_train, y_train_split, 
        validation_data=(X_val, y_val),
        epochs=200,
        batch_size=32,
        callbacks=[callbacks],
        class_weight=weight,
       )
# Out:
# Epoch 1/200
# 2024-10-14 20:49:20.041636: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8906
# W0000 00:00:1728953360.126461   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.205515   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.206027   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.216409   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.216890   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.217343   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.217758   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.218939   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.224729   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.225147   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.225604   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.226036   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.226494   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.227002   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.235638   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953360.237360   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.577914   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.578522   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.579024   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.579521   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.580044   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.580563   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.581082   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.581580   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.582045   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.582505   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.583082   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.583650   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.584111   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.584614   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.585215   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.585731   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.594167   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.594593   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.595034   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.595534   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.596016   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.596448   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.596888   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.597333   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.597766   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.598171   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.598618   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.599080   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.599454   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.599904   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.600390   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953361.600875   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.043161   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.043710   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.046699   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.047258   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.052991   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.053429   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.054246   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.054711   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.055174   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.055628   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.090126   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.091130   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.091919   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.092303   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.093752   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.094184   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.098365   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.098886   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.099668   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.100475   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.104859   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.105437   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.136932   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.137448   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.137948   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.138380   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.138869   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.139353   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.139850   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.141790   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.142258   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.142683   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.143446   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.143867   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.144399   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.144847   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.145723   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.150131   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.150551   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.151008   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.151701   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.152126   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.152912   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.153464   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.154253   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.154681   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953363.155592   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5046 - loss: 1.0334
# W0000 00:00:1728953381.710057   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.710445   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.710856   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.711260   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.711658   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.712071   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.712502   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.712903   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.713306   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.713688   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.714148   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.714553   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.714950   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.715337   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.719200   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.719546   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.719910   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.738792   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.739229   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.739659   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.740074   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.740506   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.740975   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.741417   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.741880   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.742373   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.742833   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.743278   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.743734   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.744202   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.744702   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.745208   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.752853   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.753305   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.753754   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.754187   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.754593   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.755038   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.755448   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.755888   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.756280   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.756720   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.757124   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.757555   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.757914   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.758343   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.758772   23340 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.779952   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.780289   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.780668   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.781076   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.781466   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.781892   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.782317   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.782714   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.783250   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.786668   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.787059   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.787484   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.787867   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.788208   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.788567   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.788925   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.789255   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.789699   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.790130   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.793719   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.794097   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.794474   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.794878   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.795304   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.795686   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.796140   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.796550   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.797020   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.800204   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.800578   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.800954   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.801328   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.801718   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.802112   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.802475   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.802866   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.803292   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.803704   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.807448   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.807805   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.808220   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.808590   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.808926   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.809299   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.809689   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.810131   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.810502   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953381.810866   23333 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Epoch 1: val_loss improved from inf to 0.68951, saving model to model_weights_spec.weights.h5
# W0000 00:00:1728953384.801860   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.802315   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.802749   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.803188   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.803596   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.803998   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.804415   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.804815   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.805187   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.805566   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.805991   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.806393   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.806779   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.807159   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.807555   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.808088   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.815567   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.816011   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.816447   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.816893   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.817323   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.817774   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.818320   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.818777   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.819247   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.819740   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.820181   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.820629   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.821070   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.821565   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.822136   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.822649   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.831342   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.831770   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.832181   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.832554   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.832978   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.833394   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.833893   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.834323   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.834779   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.835223   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.835633   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.836062   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.836493   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.836947   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.837396   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1728953384.837851   23336 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.5046 - loss: 1.0334 - val_accuracy: 0.7369 - val_loss: 0.6895 - learning_rate: 0.0010
# Epoch 2/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5325 - loss: 1.0218
# Epoch 2: val_loss did not improve from 0.68951
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.5323 - loss: 1.0218 - val_accuracy: 0.7369 - val_loss: 0.6922 - learning_rate: 0.0010
# Epoch 3/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4114 - loss: 1.0239
# Epoch 3: val_loss did not improve from 0.68951
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.4115 - loss: 1.0239 - val_accuracy: 0.7369 - val_loss: 0.6915 - learning_rate: 0.0010
# Epoch 4/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5478 - loss: 1.0216
# Epoch 4: val_loss improved from 0.68951 to 0.68546, saving model to model_weights_spec.weights.h5
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.5477 - loss: 1.0216 - val_accuracy: 0.7369 - val_loss: 0.6855 - learning_rate: 0.0010
# Epoch 5/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4696 - loss: 1.0226
# Epoch 5: val_loss did not improve from 0.68546
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.4696 - loss: 1.0226 - val_accuracy: 0.5685 - val_loss: 0.6944 - learning_rate: 0.0010
# Epoch 6/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4015 - loss: 1.0233
# Epoch 6: val_loss improved from 0.68546 to 0.67535, saving model to model_weights_spec.weights.h5
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.4016 - loss: 1.0232 - val_accuracy: 0.7369 - val_loss: 0.6754 - learning_rate: 0.0010
# Epoch 7/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4505 - loss: 1.0194
# Epoch 7: val_loss did not improve from 0.67535
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.4505 - loss: 1.0194 - val_accuracy: 0.2631 - val_loss: 0.6991 - learning_rate: 0.0010
# Epoch 8/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3428 - loss: 1.0222
# Epoch 8: val_loss did not improve from 0.67535
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.3431 - loss: 1.0222 - val_accuracy: 0.2631 - val_loss: 0.6951 - learning_rate: 0.0010
# Epoch 9/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5196 - loss: 1.0209
# Epoch 9: val_loss did not improve from 0.67535
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5196 - loss: 1.0209 - val_accuracy: 0.7361 - val_loss: 0.6925 - learning_rate: 0.0010
# Epoch 10/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6068 - loss: 1.0194
# Epoch 10: val_loss improved from 0.67535 to 0.67214, saving model to model_weights_spec.weights.h5
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6067 - loss: 1.0194 - val_accuracy: 0.7354 - val_loss: 0.6721 - learning_rate: 0.0010
# Epoch 11/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5659 - loss: 1.0210
# Epoch 11: val_loss did not improve from 0.67214
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5659 - loss: 1.0210 - val_accuracy: 0.7368 - val_loss: 0.6742 - learning_rate: 0.0010
# Epoch 12/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5773 - loss: 1.0192
# Epoch 12: val_loss did not improve from 0.67214
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5773 - loss: 1.0192 - val_accuracy: 0.2631 - val_loss: 0.6986 - learning_rate: 0.0010
# Epoch 13/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4499 - loss: 1.0216
# Epoch 13: val_loss did not improve from 0.67214
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.4501 - loss: 1.0215 - val_accuracy: 0.7303 - val_loss: 0.6846 - learning_rate: 0.0010
# Epoch 14/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5600 - loss: 1.0228
# Epoch 14: val_loss did not improve from 0.67214
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5601 - loss: 1.0228 - val_accuracy: 0.7361 - val_loss: 0.6879 - learning_rate: 0.0010
# Epoch 15/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6113 - loss: 1.0217
# Epoch 15: val_loss did not improve from 0.67214
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6112 - loss: 1.0217 - val_accuracy: 0.7358 - val_loss: 0.6851 - learning_rate: 0.0010
# Epoch 16/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6024 - loss: 1.0183
# Epoch 16: val_loss did not improve from 0.67214
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6024 - loss: 1.0183 - val_accuracy: 0.7356 - val_loss: 0.6847 - learning_rate: 0.0010
# Epoch 17/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6128 - loss: 1.0116
# Epoch 17: val_loss improved from 0.67214 to 0.66756, saving model to model_weights_spec.weights.h5
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6128 - loss: 1.0116 - val_accuracy: 0.7368 - val_loss: 0.6676 - learning_rate: 0.0010
# Epoch 18/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6270 - loss: 1.0085
# Epoch 18: val_loss improved from 0.66756 to 0.65915, saving model to model_weights_spec.weights.h5
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6270 - loss: 1.0085 - val_accuracy: 0.7351 - val_loss: 0.6591 - learning_rate: 0.0010
# Epoch 19/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6318 - loss: 1.0019
# Epoch 19: val_loss did not improve from 0.65915
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6318 - loss: 1.0019 - val_accuracy: 0.7354 - val_loss: 0.6643 - learning_rate: 0.0010
# Epoch 20/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6163 - loss: 1.0108
# Epoch 20: val_loss did not improve from 0.65915
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.6163 - loss: 1.0108 - val_accuracy: 0.7347 - val_loss: 0.6669 - learning_rate: 0.0010
# Epoch 21/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6257 - loss: 1.0070
# Epoch 21: val_loss did not improve from 0.65915
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6257 - loss: 1.0070 - val_accuracy: 0.7337 - val_loss: 0.6607 - learning_rate: 0.0010
# Epoch 22/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6236 - loss: 1.0037
# Epoch 22: val_loss did not improve from 0.65915
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.6236 - loss: 1.0037 - val_accuracy: 0.7329 - val_loss: 0.6667 - learning_rate: 0.0010
# Epoch 23/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6513 - loss: 1.0021
# Epoch 23: val_loss did not improve from 0.65915
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.6512 - loss: 1.0021 - val_accuracy: 0.7329 - val_loss: 0.6627 - learning_rate: 0.0010
# Epoch 24/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6366 - loss: 1.0032
# Epoch 24: val_loss improved from 0.65915 to 0.63393, saving model to model_weights_spec.weights.h5
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.6366 - loss: 1.0032 - val_accuracy: 0.7352 - val_loss: 0.6339 - learning_rate: 0.0010
# Epoch 25/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6316 - loss: 1.0063
# Epoch 25: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6316 - loss: 1.0063 - val_accuracy: 0.7335 - val_loss: 0.6596 - learning_rate: 0.0010
# Epoch 26/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6194 - loss: 1.0028
# Epoch 26: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6194 - loss: 1.0028 - val_accuracy: 0.7157 - val_loss: 0.6457 - learning_rate: 0.0010
# Epoch 27/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6288 - loss: 0.9964
# Epoch 27: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6288 - loss: 0.9964 - val_accuracy: 0.6455 - val_loss: 0.6575 - learning_rate: 0.0010
# Epoch 28/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6057 - loss: 0.9984
# Epoch 28: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6057 - loss: 0.9984 - val_accuracy: 0.7285 - val_loss: 0.6342 - learning_rate: 0.0010
# Epoch 29/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6535 - loss: 0.9885
# Epoch 29: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6534 - loss: 0.9885 - val_accuracy: 0.7113 - val_loss: 0.6694 - learning_rate: 0.0010
# Epoch 30/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6438 - loss: 0.9891
# Epoch 30: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6437 - loss: 0.9891 - val_accuracy: 0.6778 - val_loss: 0.6701 - learning_rate: 0.0010
# Epoch 31/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6481 - loss: 0.9800
# Epoch 31: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.6481 - loss: 0.9800 - val_accuracy: 0.5593 - val_loss: 0.6856 - learning_rate: 0.0010
# Epoch 32/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6463 - loss: 0.9852
# Epoch 32: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6463 - loss: 0.9852 - val_accuracy: 0.5666 - val_loss: 0.6828 - learning_rate: 0.0010
# Epoch 33/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6440 - loss: 0.9764
# Epoch 33: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6441 - loss: 0.9764 - val_accuracy: 0.6181 - val_loss: 0.6734 - learning_rate: 0.0010
# Epoch 34/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6456 - loss: 0.9725
# Epoch 34: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6456 - loss: 0.9725 - val_accuracy: 0.5457 - val_loss: 0.6831 - learning_rate: 0.0010
# Epoch 35/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6857 - loss: 0.9579
# Epoch 35: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6857 - loss: 0.9580 - val_accuracy: 0.5626 - val_loss: 0.6779 - learning_rate: 1.0000e-04
# Epoch 36/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6849 - loss: 0.9498
# Epoch 36: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6849 - loss: 0.9498 - val_accuracy: 0.5640 - val_loss: 0.6839 - learning_rate: 1.0000e-04
# Epoch 37/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6877 - loss: 0.9496
# Epoch 37: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6877 - loss: 0.9496 - val_accuracy: 0.5165 - val_loss: 0.7030 - learning_rate: 1.0000e-04
# Epoch 38/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6823 - loss: 0.9518
# Epoch 38: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6823 - loss: 0.9518 - val_accuracy: 0.5298 - val_loss: 0.7031 - learning_rate: 1.0000e-04
# Epoch 39/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6922 - loss: 0.9357
# Epoch 39: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6922 - loss: 0.9357 - val_accuracy: 0.5480 - val_loss: 0.6964 - learning_rate: 1.0000e-04
# Epoch 1/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6847 - loss: 0.9451
# Epoch 1: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.6847 - loss: 0.9451 - val_accuracy: 0.5565 - val_loss: 0.6920 - learning_rate: 1.0000e-04
# Epoch 2/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6846 - loss: 0.9433
# Epoch 2: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.6847 - loss: 0.9433 - val_accuracy: 0.5632 - val_loss: 0.6935 - learning_rate: 1.0000e-04
# Epoch 3/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6895 - loss: 0.9395
# Epoch 3: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.6895 - loss: 0.9395 - val_accuracy: 0.5761 - val_loss: 0.6828 - learning_rate: 1.0000e-04
# Epoch 4/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6959 - loss: 0.9344
# Epoch 4: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6959 - loss: 0.9344 - val_accuracy: 0.6145 - val_loss: 0.6722 - learning_rate: 1.0000e-04
# Epoch 5/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7006 - loss: 0.9191
# Epoch 5: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7006 - loss: 0.9191 - val_accuracy: 0.5886 - val_loss: 0.6866 - learning_rate: 1.0000e-04
# Epoch 6/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6918 - loss: 0.9358
# Epoch 6: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6918 - loss: 0.9358 - val_accuracy: 0.6023 - val_loss: 0.6758 - learning_rate: 1.0000e-04
# Epoch 7/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6965 - loss: 0.9362
# Epoch 7: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6965 - loss: 0.9362 - val_accuracy: 0.6249 - val_loss: 0.6680 - learning_rate: 1.0000e-04
# Epoch 8/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6971 - loss: 0.9173
# Epoch 8: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6971 - loss: 0.9173 - val_accuracy: 0.6133 - val_loss: 0.6752 - learning_rate: 1.0000e-04
# Epoch 9/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6983 - loss: 0.9261
# Epoch 9: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6983 - loss: 0.9261 - val_accuracy: 0.6393 - val_loss: 0.6649 - learning_rate: 1.0000e-04
# Epoch 10/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7060 - loss: 0.9283
# Epoch 10: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7060 - loss: 0.9283 - val_accuracy: 0.6078 - val_loss: 0.6761 - learning_rate: 1.0000e-04
# Epoch 11/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7102 - loss: 0.9154
# Epoch 11: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7102 - loss: 0.9154 - val_accuracy: 0.5977 - val_loss: 0.6800 - learning_rate: 1.0000e-04
# Epoch 12/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7064 - loss: 0.9148
# Epoch 12: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7063 - loss: 0.9148 - val_accuracy: 0.5751 - val_loss: 0.6880 - learning_rate: 1.0000e-04
# Epoch 13/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7060 - loss: 0.9118
# Epoch 13: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7060 - loss: 0.9118 - val_accuracy: 0.6165 - val_loss: 0.6672 - learning_rate: 1.0000e-04
# Epoch 14/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7023 - loss: 0.9213
# Epoch 14: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7023 - loss: 0.9213 - val_accuracy: 0.6245 - val_loss: 0.6679 - learning_rate: 1.0000e-04
# Epoch 15/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7047 - loss: 0.9084
# Epoch 15: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7047 - loss: 0.9084 - val_accuracy: 0.6111 - val_loss: 0.6710 - learning_rate: 1.0000e-04
# Epoch 1/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7051 - loss: 0.9176
# Epoch 1: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7051 - loss: 0.9176 - val_accuracy: 0.6491 - val_loss: 0.6549 - learning_rate: 1.0000e-04
# Epoch 2/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7078 - loss: 0.9058
# Epoch 2: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 22s 24ms/step - accuracy: 0.7078 - loss: 0.9058 - val_accuracy: 0.6345 - val_loss: 0.6633 - learning_rate: 1.0000e-04
# Epoch 3/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7070 - loss: 0.9055
# Epoch 3: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7070 - loss: 0.9055 - val_accuracy: 0.6167 - val_loss: 0.6682 - learning_rate: 1.0000e-04
# Epoch 4/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6967 - loss: 0.9179
# Epoch 4: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6967 - loss: 0.9179 - val_accuracy: 0.6372 - val_loss: 0.6616 - learning_rate: 1.0000e-04
# Epoch 5/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7065 - loss: 0.9147
# Epoch 5: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7065 - loss: 0.9147 - val_accuracy: 0.6101 - val_loss: 0.6718 - learning_rate: 1.0000e-04
# Epoch 6/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7133 - loss: 0.9016
# Epoch 6: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7133 - loss: 0.9017 - val_accuracy: 0.6488 - val_loss: 0.6642 - learning_rate: 1.0000e-04
# Epoch 7/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7183 - loss: 0.8933
# Epoch 7: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7183 - loss: 0.8933 - val_accuracy: 0.6517 - val_loss: 0.6565 - learning_rate: 1.0000e-04
# Epoch 8/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7183 - loss: 0.9023
# Epoch 8: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7183 - loss: 0.9023 - val_accuracy: 0.6619 - val_loss: 0.6525 - learning_rate: 1.0000e-04
# Epoch 9/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7200 - loss: 0.8918
# Epoch 9: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7200 - loss: 0.8918 - val_accuracy: 0.6483 - val_loss: 0.6609 - learning_rate: 1.0000e-04
# Epoch 10/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7098 - loss: 0.8978
# Epoch 10: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7098 - loss: 0.8978 - val_accuracy: 0.6627 - val_loss: 0.6502 - learning_rate: 1.0000e-04
# Epoch 11/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7190 - loss: 0.8870
# Epoch 11: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7190 - loss: 0.8871 - val_accuracy: 0.5744 - val_loss: 0.6961 - learning_rate: 1.0000e-04
# Epoch 12/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7153 - loss: 0.8815
# Epoch 12: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7153 - loss: 0.8815 - val_accuracy: 0.5818 - val_loss: 0.6917 - learning_rate: 1.0000e-04
# Epoch 13/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7177 - loss: 0.8821
# Epoch 13: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7177 - loss: 0.8821 - val_accuracy: 0.5807 - val_loss: 0.6889 - learning_rate: 1.0000e-04
# Epoch 14/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7251 - loss: 0.8783
# Epoch 14: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7251 - loss: 0.8783 - val_accuracy: 0.6105 - val_loss: 0.6763 - learning_rate: 1.0000e-04
# Epoch 15/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7214 - loss: 0.8765
# Epoch 15: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7214 - loss: 0.8765 - val_accuracy: 0.6049 - val_loss: 0.6757 - learning_rate: 1.0000e-04
# Epoch 1/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7198 - loss: 0.8802
# Epoch 1: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7198 - loss: 0.8802 - val_accuracy: 0.6130 - val_loss: 0.6778 - learning_rate: 1.0000e-04
# Epoch 2/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7177 - loss: 0.8832
# Epoch 2: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7177 - loss: 0.8832 - val_accuracy: 0.5666 - val_loss: 0.7007 - learning_rate: 1.0000e-04
# Epoch 3/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7231 - loss: 0.8761
# Epoch 3: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7231 - loss: 0.8761 - val_accuracy: 0.5949 - val_loss: 0.6817 - learning_rate: 1.0000e-04
# Epoch 4/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7318 - loss: 0.8687
# Epoch 4: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7318 - loss: 0.8687 - val_accuracy: 0.5808 - val_loss: 0.6867 - learning_rate: 1.0000e-04
# Epoch 5/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7241 - loss: 0.8749
# Epoch 5: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7241 - loss: 0.8749 - val_accuracy: 0.5664 - val_loss: 0.7024 - learning_rate: 1.0000e-04
# Epoch 6/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7358 - loss: 0.8589
# Epoch 6: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7358 - loss: 0.8589 - val_accuracy: 0.5370 - val_loss: 0.7059 - learning_rate: 1.0000e-04
# Epoch 7/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7206 - loss: 0.8605
# Epoch 7: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7206 - loss: 0.8605 - val_accuracy: 0.5599 - val_loss: 0.6986 - learning_rate: 1.0000e-04
# Epoch 8/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7320 - loss: 0.8486
# Epoch 8: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7320 - loss: 0.8486 - val_accuracy: 0.5579 - val_loss: 0.7020 - learning_rate: 1.0000e-04
# Epoch 9/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7279 - loss: 0.8628
# Epoch 9: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7279 - loss: 0.8628 - val_accuracy: 0.5551 - val_loss: 0.7068 - learning_rate: 1.0000e-04
# Epoch 10/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7405 - loss: 0.8390
# Epoch 10: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7405 - loss: 0.8390 - val_accuracy: 0.5120 - val_loss: 0.7321 - learning_rate: 1.0000e-04
# Epoch 11/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7268 - loss: 0.8594
# Epoch 11: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7268 - loss: 0.8594 - val_accuracy: 0.5594 - val_loss: 0.7109 - learning_rate: 1.0000e-04
# Epoch 12/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7222 - loss: 0.8541
# Epoch 12: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7222 - loss: 0.8541 - val_accuracy: 0.5499 - val_loss: 0.7035 - learning_rate: 1.0000e-05
# Epoch 13/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7293 - loss: 0.8372
# Epoch 13: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7293 - loss: 0.8372 - val_accuracy: 0.5567 - val_loss: 0.7116 - learning_rate: 1.0000e-05
# Epoch 14/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7284 - loss: 0.8493
# Epoch 14: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7284 - loss: 0.8493 - val_accuracy: 0.5406 - val_loss: 0.7197 - learning_rate: 1.0000e-05
# Epoch 15/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7322 - loss: 0.8490
# Epoch 15: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7322 - loss: 0.8490 - val_accuracy: 0.5629 - val_loss: 0.7036 - learning_rate: 1.0000e-05
# Epoch 1/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7322 - loss: 0.8502
# Epoch 1: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7322 - loss: 0.8502 - val_accuracy: 0.5569 - val_loss: 0.7099 - learning_rate: 1.0000e-05
# Epoch 2/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7285 - loss: 0.8457
# Epoch 2: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7285 - loss: 0.8457 - val_accuracy: 0.5191 - val_loss: 0.7316 - learning_rate: 1.0000e-05
# Epoch 3/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7345 - loss: 0.8424
# Epoch 3: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7345 - loss: 0.8425 - val_accuracy: 0.5641 - val_loss: 0.7024 - learning_rate: 1.0000e-05
# Epoch 4/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7243 - loss: 0.8590
# Epoch 4: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7243 - loss: 0.8590 - val_accuracy: 0.5605 - val_loss: 0.7045 - learning_rate: 1.0000e-05
# Epoch 5/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7288 - loss: 0.8465
# Epoch 5: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7288 - loss: 0.8465 - val_accuracy: 0.5493 - val_loss: 0.7120 - learning_rate: 1.0000e-05
# Epoch 6/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7293 - loss: 0.8429
# Epoch 6: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7293 - loss: 0.8429 - val_accuracy: 0.5271 - val_loss: 0.7265 - learning_rate: 1.0000e-05
# Epoch 7/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7253 - loss: 0.8491
# Epoch 7: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7253 - loss: 0.8491 - val_accuracy: 0.5521 - val_loss: 0.7064 - learning_rate: 1.0000e-05
# Epoch 8/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7307 - loss: 0.8411
# Epoch 8: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7307 - loss: 0.8411 - val_accuracy: 0.5509 - val_loss: 0.7090 - learning_rate: 1.0000e-05
# Epoch 9/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7331 - loss: 0.8445
# Epoch 9: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - accuracy: 0.7331 - loss: 0.8445 - val_accuracy: 0.5281 - val_loss: 0.7273 - learning_rate: 1.0000e-05
# Epoch 10/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7281 - loss: 0.8416
# Epoch 10: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7281 - loss: 0.8417 - val_accuracy: 0.5530 - val_loss: 0.7124 - learning_rate: 1.0000e-05
# Epoch 11/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7237 - loss: 0.8472
# Epoch 11: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7237 - loss: 0.8472 - val_accuracy: 0.5529 - val_loss: 0.7070 - learning_rate: 1.0000e-05
# Epoch 12/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7214 - loss: 0.8481
# Epoch 12: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7214 - loss: 0.8481 - val_accuracy: 0.5255 - val_loss: 0.7186 - learning_rate: 1.0000e-05
# Epoch 13/200
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7307 - loss: 0.8422
# Epoch 13: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7307 - loss: 0.8422 - val_accuracy: 0.5440 - val_loss: 0.7131 - learning_rate: 1.0000e-05
# Epoch 14/200
# 928/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7286 - loss: 0.8381
# Epoch 14: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7286 - loss: 0.8381 - val_accuracy: 0.5180 - val_loss: 0.7225 - learning_rate: 1.0000e-05
# Epoch 15/200
# 929/930 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7263 - loss: 0.8421
# Epoch 15: val_loss did not improve from 0.63393
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7263 - loss: 0.8422 - val_accuracy: 0.5633 - val_loss: 0.6984 - learning_rate: 1.0000e-05

# %%
fig = plt.figure(figsize=(12, 5))
fig.add_subplot(121)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model: loss vs epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')

fig.add_subplot(122)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model: acc vs epochs')
plt.ylabel('Acc')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %% [markdown]
# #### Predictions

# %%
# model.load_weights('model_weights_spec.weights.h5')
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
preds = model.predict(X_test_processed)
model.evaluate(X_test_processed, y_test)
# Out:
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5592 - loss: 0.7022
# [0.7027972340583801, 0.5609514713287354]

# %%
cm = confusion_matrix(y_test, np.argmax(preds, axis=1))

# Número de clases
num_classes = cm.shape[0]

# Normalizar la matriz de confusión
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Graficar
plt.figure(figsize=(8, 6))  # Opcional, para ajustar el tamaño de la figura
plt.imshow(cm_normalized, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, range(num_classes), rotation=45)
plt.yticks(tick_marks, range(num_classes))

# Anotar la matriz
for i, j in itertools.product(range(cm_normalized.shape[0]), range(cm_normalized.shape[1])):
    plt.text(j, i, f"{cm_normalized[i, j]:.2%}",
             horizontalalignment="center",
             color="white" if cm_normalized[i, j] > 0.5 else "black")

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
roc_auc_score(y_test, np.argmax(preds, axis=1))
# Out:
# 0.5240455579582143

# %%
accuracy_score(y_test, np.argmax(preds, axis=1))
# Out:
# 0.5609514915123881

# %%
print(classification_report(y_test, np.argmax(preds, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.45      0.35      4790
#            1       0.75      0.60      0.67     13413
#
#     accuracy                           0.56     18203
#    macro avg       0.52      0.52      0.51     18203
# weighted avg       0.63      0.56      0.58     18203
