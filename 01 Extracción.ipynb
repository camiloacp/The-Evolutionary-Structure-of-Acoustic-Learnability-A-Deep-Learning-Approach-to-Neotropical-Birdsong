# %%
#Inspeccionar y cambiar paquetes
#import inspect
#import librosa

#print(inspect.getfile(librosa.beat.beat_track))

# %%
# manejo de datos
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# api Xenocanto
from xenopy import Query
from scipy import signal
import scipy.signal.windows

# manejo de audio
import librosa
import librosa.display

# %% [markdown]
# ## **Familia Thamnophilidae**

# %%
thamnophilidae_euchrepomis = ['Euchrepomis callinota', 'Euchrepomis humeralis', 'Euchrepomis spodioptila']
thamnophilidae_cymbilaimus = ['Cymbilaimus lineatus']
thamnophilidae_frederickena = ['Frederickena unduliger', 'Frederickena fulva']
thamnophilidae_taraba = ['Taraba major']
thamnophilidae_sakesphorus = ['Sakesphorus canadensis']
thamnophilidae_thamnophilus = ['Thamnophilus doliatus', 'Thamnophilus multistriatus', 'Thamnophilus tenuepunctatus', 'Thamnophilus atrinucha',
                            'Thamnophilus schistaceus', 'Thamnophilus murinus', 'Thamnophilus nigriceps', 'Thamnophilus praecox', 
                            'Thamnophilus cryptoleucus', 'Thamnophilus nigrocinereus', 'Thamnophilus punctatus', 'Thamnophilus unicolor',
                            'Thamnophilus aethiops', 'Thamnophilus melanonotus', 'Thamnophilus amazonicus']
thamnophilidae_megastictus = ['Megastictus margaritatus']
thamnophilidae_neoctantes = ['Neoctantes niger']
thamnophilidae_clytoctantes = ['Clytoctantes alixii']
thamnophilidae_thamnistes = ['Thamnistes anabatinus']
thamnophilidae_dysithamnus = ['Dysithamnus mentalis', 'Dysithamnus puncticeps', 'Dysithamnus occidentalis', 'Dysithamnus leucostictus']
thamnophilidae_thamnomanes = ['Thamnomanes ardesiacus', 'Thamnomanes caesius']
thamnophilidae_xenornis = ['Xenornis setifrons']
thamnophilidae_isleria = ['Isleria hauxwelli']
thamnophilidae_pygiptila = ['Pygiptila stellaris']
thamnophilidae_epinecrophylla = ['Epinecrophylla fulviventris', 'Epinecrophylla haematonota', 'Epinecrophylla ornata', 'Epinecrophylla spodionota', 'Epinecrophylla erythrura']
thamnophilidae_myrmotherula = ['Myrmotherula brachyura', 'Myrmotherula ignota', 'Myrmotherula ambigua', 'Myrmotherula surinamensis', 'Myrmotherula multostriata',
                            'Myrmotherula pacifica', 'Myrmotherula cherriei', 'Myrmotherula longicauda', 'Myrmotherula axillaris', 'Myrmotherula schisticolor',
                            'Myrmotherula sunensis', 'Myrmotherula longipennis', 'Myrmotherula behni', 'Myrmotherula menetriesii', 'Myrmotherula assimilis']
thamnophilidae_dichrozona = ['Dichrozona cincta']
thamnophilidae_herpsilochmus = ['Herpsilochmus dugandi', 'Herpsilochmus dorsimaculatus', 'Herpsilochmus axillaris', 'Herpsilochmus rufimarginatus']
thamnophilidae_microrhopias = ['Microrhopias quixensis']
thamnophilidae_formicivora = ['Formicivora grisea']
thamnophilidae_drymophila = ['Drymophila devillei', 'Drymophila hellmayri', 'Drymophila klagesi', 'Drymophila caudata', 'Drymophila striaticeps']
thamnophilidae_hypocnemis = ['Hypocnemis flavescens', 'Hypocnemis peruviana', 'Hypocnemis hypoxantha']
thamnophilidae_cercomacroides = ['Cercomacroides parkeri', 'Cercomacroides tyrannina', 'Cercomacroides serva', 'Cercomacroides nigrescens', 'Cercomacroides fuscicauda']
    thamnophilidae_pithys, thamnophilidae_gymnopithys, thamnophilidae_rhegmatorhina, thamnophilidae_hylophylax, thamnophilidae_willisornis, thamnophilidae_phlegopsis, thamnophilidae_phaenostictus
    ]

# %% [markdown]
# ## **Familia Conopophagidae**

# %%
conopophagidae_conopophaga = ['Conopophaga aurita', 'Conopophaga castaneiceps']
conopophagidae_pittasoma = ['Pittasoma michleri', 'Pittasoma rufopileatum']

# %%
conopophagidae= [conopophagidae_conopophaga, conopophagidae_pittasoma]

# %% [markdown]
# ## **Familia Grallaridae**

# %%
grallaridae_grallaria = ['Grallaria squamigera', 'Grallaria gigantea', 'Grallaria alleni', ' Grallaria guatimalensis', 'Grallaria haplonota', 'Grallaria dignissima', 'Grallaria bangsi',
                         'Grallaria ruficapilla', 'Grallaria kaestneri', 'Grallaria rufocinerea', 'Grallaria nuchalis', 'Grallaria flavotincta', 'Grallaria flavotincta', 'Grallaria quitensis',
                         'Grallaria urraoensis', 'Grallaria milleri']
grallaridae_hylopezus = ['Hylopezus perspicillatus', 'Hylopezus macularius', 'Hylopezus fulviventris']
grallaridae_myrmothera = ['Myrmothera campanisona']
grallaridae_grallaricula = ['Grallaricula flavirostris', 'Grallaricula cucullata', 'Grallaricula ferrugineipectus', 'Grallaricula nana', 'Grallaricula lineifrons']

# %%
grallaridae = [grallaridae_grallaria, grallaridae_hylopezus, grallaridae_myrmothera, grallaridae_grallaricula]

# %% [markdown]
# ## **Familia Rhinocryptidae**

# %%
rhinocryptidae_liosceles = ['Liosceles thoracicus']
rhinocryptidae_acropternis = ['Acropternis orthonyx']
rhinocryptidae_myornis = ['Myornis senilis']
rhinocryptidae_scytalopus = ['Scytalopus latrans', 'Scytalopus sanctaemartae', 'Scytalopus micropterus', 'Scytalopus atratus', 'Scytalopus panamensis', 'Scytalopus chocoensis',
                             'Scytalopus alvarezlopezi', 'Scytalopus rodriguezi', 'Scytalopus stilesi', 'Scytalopus vicinior', 'Scytalopus latebricola', 'Scytalopus perijanus',
                             'Scytalopus spillmanni', 'Scytalopus griseicollis', 'Scytalopus canus', 'Scytalopus opacus']

# %%
rhinocryptidae = [rhinocryptidae_liosceles, rhinocryptidae_acropternis, rhinocryptidae_myornis, rhinocryptidae_scytalopus]

# %% [markdown]
# ## **Familia Formicariidae**

# %%
formicariidae_formicarius = ['Formicarius analis', 'Formicarius rufipectus', 'Formicarius colma', 'Formicarius nigricapillus']
formicariidae_chamaeze = ['Chamaeza campanisona', 'Chamaeza nobilis', 'Chamaeza nobilis', 'Chamaeza mollissima']

# %%
formicariidae = [formicariidae_formicarius, formicariidae_chamaeze]

# %% [markdown]
# ## **Familia Furnariidae**

# %%
furnariidae_sclerurus = ['Sclerurus mexicanus', 'Sclerurus rufigularis', 'Sclerurus guatemalensis', 'Sclerurus caudacutus', 'Sclerurus albigularis', 'Sclerurus obscurior']
furnariidae_certhiasomus = ['Certhiasomus stictolaemus']
furnariidae_sittasomus = ['Sittasomus griseicapillus']
furnariidae_deconychura = ['Deconychura longicauda']
furnariidae_dendrocincla = ['Dendrocincla tyrannina', 'Dendrocincla merula', 'Dendrocincla homochroa', 'Dendrocincla fuliginosa']
cotingidae_haematoderus = ['Haematoderus militaris']
cotingidae_querula = ['Querula purpurata']
cotingidae_pyroderus = ['Pyroderus scutatus']
cotingidae_cephalopterus = ['Cephalopterus penduliger', 'Cephalopterus ornatus']
cotingidae_perissocephalus = ['Perissocephalus tricolor']
cotingidae_cotinga = ['Cotinga nattererii', 'Cotinga maynana', 'Cotinga cotinga', 'Cotinga cayana']
cotingidae_lipaugus = ['Lipaugus weberi', 'Lipaugus fuscocinereus', 'Lipaugus unirufus', 'Lipaugus vociferans']
cotingidae_porphyrolaema = ['Porphyrolaema porphyrolaema']
cotingidae_procnias = ['Procnias averano']
cotingidae_xipholena = ['Xipholena punicea']
cotingidae_carpodectes = ['Carpodectes hopkei']
cotingidae_gymnoderus = ['Gymnoderus foetidus']

# %%
cotingidae = [cotingidae_pipreola, cotingidae_ampelioides, cotingidae_doliornis, cotingidae_ampelion, cotingidae_phoenicircus, cotingidae_rupicola, cotingidae_snowornis,
            cotingidae_haematoderus, cotingidae_querula, cotingidae_pyroderus, cotingidae_cephalopterus, cotingidae_perissocephalus, cotingidae_cotinga, cotingidae_lipaugus,
            cotingidae_porphyrolaema, cotingidae_procnias, cotingidae_xipholena, cotingidae_carpodectes, cotingidae_gymnoderus]

# %% [markdown]
# ## **Familia Pipridae**

# %%
pipridae_tyranneutes = ['Tyranneutes stolzmanni']
pipridae_neopelma = ['Neopelma chrysocephalum']
pipridae_chloropipo = ['Chloropipo flavicapilla'] 
pipridae_chiroxiphia = ['Chiroxiphia lanceolata', 'Chiroxiphia lanceolata']
pipridae_masius = ['Masius chrysopterus']
pipridae_corapipo = ['Corapipo altera', 'Corapipo leucorrhoa']
pipridae_xenopipo = ['Xenopipo atronitens']
pipridae_cryptopipo = ['Cryptopipo holochlora']
pipridae_lepidothrix = ['Lepidothrix coronata', 'Lepidothrix isidorei']
pipridae_heterocercus = ['Heterocercus flavivertex']
pipridae_manacus = ['Manacus manacus'] 
pipridae_pipra = ['Pipra filicauda']
pipridae_machaeropterus = ['Machaeropterus deliciosus', 'Machaeropterus regulus']
pipridae_ceratopipra = ['Ceratopipra mentalis', 'Ceratopipra erythrocephala']

# %%
pipridae = [pipridae_tyranneutes, pipridae_neopelma, pipridae_chloropipo, pipridae_chiroxiphia, pipridae_masius, pipridae_corapipo, pipridae_xenopipo, pipridae_cryptopipo,
            pipridae_lepidothrix, pipridae_heterocercus, pipridae_manacus, pipridae_pipra, pipridae_machaeropterus, pipridae_ceratopipra]

# %% [markdown]
# ## **Familia Tityridae**

# %%
tityridae_tityra = ['Tityra semifasciata', 'Tityra inquisitor', 'Tityra cayana']
tityridae_schiffornis = ['Schiffornis major', 'Schiffornis veraepacis', 'Schiffornis aenea', 'Schiffornis stenorhyncha', 'Schiffornis turdina']
tityridae_laniocera = ['Laniocera rufescens', 'Laniocera hypopyrra']
tityridae_iodopleura = ['Iodopleura isabellae']
tityridae_laniisoma = ['Laniisoma elegans']
tityridae_pachyramphus = ['Pachyramphus viridis', 'Pachyramphus versicolor', 'Pachyramphus rufus', 'Pachyramphus cinnamomeus', 'Pachyramphus polychopterus', 'Pachyramphus albogriseus',
                          'Pachyramphus marginatus', 'Pachyramphus homochrous', 'Pachyramphus minor']

# %%
tityridae = [tityridae_tityra, tityridae_schiffornis, tityridae_laniocera, tityridae_iodopleura, tityridae_laniisoma, tityridae_pachyramphus]

# %% [markdown]
# ## **Familia Vireonidae**

# %%
vireonidae_cyclarhis = ['Cyclarhis gujanensis', 'Cyclarhis nigrirostris']
vireonidae_hylophilus = ['Hylophilus flavipes', 'Hylophilus semicinereus', 'Hylophilus brunneiceps', 'Hylophilus thoracicus']
vireonidae_vireolanius = ['Vireolanius leucotis', 'Vireolanius eximius']
vireonidae_tunchiornis = ['Tunchiornis ochraceiceps'] 
vireonidae_pachysylvia = ['Pachysylvia decurtata', 'Pachysylvia aurantiifrons', 'Pachysylvia semibrunnea']
vireonidae_vireo = ['Vireo flavifrons', 'Vireo masteri', 'Vireo approximans', 'Vireo griseus', 'Vireo caribaeus',
                    'Vireo philadelphicus', 'Vireo leucophrys', 'Vireo olivaceus', 'Vireo flavoviridis', 'Vireo altiloquus']

# %%
vireonidae = [vireonidae_cyclarhis, vireonidae_hylophilus, vireonidae_vireolanius, vireonidae_tunchiornis, vireonidae_pachysylvia, vireonidae_vireo]

# %% [markdown]
# ## **Familia Corvidae**

# %%
corvidae_cyanolyca = ['Cyanolyca armillata', 'Cyanolyca turcosa', 'Cyanolyca pulchra']
corvidae_cyanocorax = ['Cyanocorax violaceus', 'Cyanocorax affinis', 'Cyanocorax heilprini', 'Cyanocorax yncas']

# %%
corvidae = [corvidae_cyanolyca, corvidae_cyanocorax]

# %% [markdown]
# ## **Familia Alaudidae**

# %%
aludidae_eremophila = ['Eremophila alpestris']
alaudidae = [aludidae_eremophila]

# %% [markdown]
# ## **Familia Hirundinidae**

# %%
hirundinidae_pygochelidon = ['Pygochelidon cyanoleuca', 'Pygochelidon melanoleuca']
hirundinidae_alopochelidon = ['Alopochelidon fucata']
hirundinidae_orochelidon = ['Orochelidon flavipes', 'Orochelidon murina']
hirundinidae_atticora = ['Atticora fasciata', 'Atticora tibialis']
hirundinidae_stelgidopteryx = ['Stelgidopteryx serripennis', 'Stelgidopteryx ruficollis']
hirundinidae_progne = ['Progne tapera', 'Progne subis', 'Progne chalybea', 'Progne elegans']
hirundinidae_tachycineta = ['Tachycineta bicolor', 'Tachycineta albiventer', 'Tachycineta thalassina', 'Tachycineta cyaneoviridis']
hirundinidae_riparia = ['Riparia riparia']
hirundinidae_hirundo = ['Hirundo rustica']
hirundinidae_petrochelidon = ['Petrochelidon pyrrhonota']

# %%
hirundinidae = [hirundinidae_pygochelidon, hirundinidae_alopochelidon, hirundinidae_orochelidon, hirundinidae_atticora, hirundinidae_stelgidopteryx, hirundinidae_progne,
                hirundinidae_tachycineta, hirundinidae_riparia, hirundinidae_hirundo, hirundinidae_petrochelidon]

# %% [markdown]
# ## **Familia Troglodytidae**

# %%
troglodytidae_microcerculus = ['Microcerculus marginatus']
troglodytidae_odontorchilus = ['Odontorchilus branickii']
troglodytidae_troglodytes = ['Troglodytes aedon', 'Troglodytes solstitialis', 'Troglodytes monticola']
troglodytidae_cistothorus = ['Cistothorus platensis', 'Cistothorus apolinari']
troglodytidae_campylorhynchus = ['Campylorhynchus albobrunneus', 'Campylorhynchus zonatus', 'Campylorhynchus nuchalis', 
                                 'Campylorhynchus griseus', 'Campylorhynchus turdinus']
troglodytidae_pheugopedius = ['Pheugopedius spadix', 'Pheugopedius fasciatoventris', 'Pheugopedius euophrys', 'Pheugopedius mystacalis',
                              'Pheugopedius coraya', 'Pheugopedius rutilus', 'Pheugopedius sclateri']
troglodytidae_thryophilus = ['Thryophilus rufalbus', 'Thryophilus sernai', 'Thryophilus nicefori']
troglodytidae_cantorchilus = ['Cantorchilus leucopogon', 'Cantorchilus nigricapillus', 'Cantorchilus leucotis']
troglodytidae_cinnycerthia = ['Cinnycerthia unirufa', 'Cinnycerthia olivascens']
troglodytidae_henicorhina = ['Henicorhina leucosticta', 'Henicorhina leucophrys', 'Henicorhina anachoreta', 'Henicorhina negreti']
troglodytidae_cyphorhinus = ['Cyphorhinus arada']

# %%
troglodytidae = [troglodytidae_microcerculus, troglodytidae_odontorchilus, troglodytidae_troglodytes, troglodytidae_cistothorus, troglodytidae_campylorhynchus,
                 troglodytidae_pheugopedius, troglodytidae_thryophilus, troglodytidae_cantorchilus, troglodytidae_cinnycerthia, troglodytidae_henicorhina,
                 troglodytidae_cyphorhinus]

# %% [markdown]
# ## **Familia Polioptilidae**

# %%
polioptilidae_microbates = ['Microbates collaris', 'Microbates cinereiventris']
polioptilidae_ramphocaenus = ['Ramphocaenus melanurus']
polioptilidae_polioptila = ['Polioptila plumbea', 'Polioptila guianensis', 'Polioptila schistaceigula']

# %%
polioptilidae = [polioptilidae_microbates, polioptilidae_ramphocaenus, polioptilidae_polioptila]

# %% [markdown]
# ## **Familia Donacobiidae**

# %%
donacobiidae_donacobius = ['Donacobius atricapilla']
donacobiidae = [donacobiidae_donacobius]

# %% [markdown]
# ## **Familia Cinclidae**

# %%
cinclidae_cinclus = ['Cinclus leucocephalus']
cinclidae = [cinclidae_cinclus]

# %% [markdown]
# ##  **Familia Bombycillidae**

# %%
bombycillidae_bombycilla = ['Bombycilla cedrorum']
bombycillidae = [bombycillidae_bombycilla]

# %% [markdown]
# ## **Familia Turdidae**

# %%
turdidae_myadestes = ['Myadestes ralloides', 'Myadestes coloratus']
turdidae_catharus = ['Catharus aurantiirostris', 'Catharus fuscater', 'Catharus dryas', 'Catharus fuscescens', 'Catharus minimus', 'Catharus ustulatus']
turdidae_hylocichla = ['Hylocichla mustelina']
turdidae_cichlopsis = ['Cichlopsis leucogenys']
turdidae_turdus = ['Turdus leucops', 'Turdus flavipes', 'Turdus leucomelas', 'Turdus fumigatus', 'Turdus hauxwelli', 'Turdus obsoletus', 'Turdus grayi', 'Turdus nudigenis', 
                   'Turdus nudigenis', 'Turdus maculirostris', 'Turdus sanchezorum', 'Turdus lawrencii', 'Turdus ignobilis', 'Turdus fulviventris', 'Turdus olivater',
                   'Turdus fuscater', 'Turdus serranus', 'Turdus assimilis', 'Turdus albicollis']

# %%
turdidae = [turdidae_myadestes, turdidae_catharus, turdidae_hylocichla, turdidae_cichlopsis, turdidae_turdus]

# %% [markdown]
# ## **Familia Mimidae**

# %%
mimidae_dumetella = ['Dumetella carolinensis']
mimidae_mimus = ['Mimus gilvus']

# %%
mimidae = [mimidae_dumetella, mimidae_mimus]

# %% [markdown]
# ## **Familia Motacillidae**

# %%
motacillidae_anthus = ['Anthus rubescens', 'Anthus lutescens', 'Anthus bogotensis']
motacillidae = [motacillidae_anthus]

# %% [markdown]
# ## **Familia Thraupidae**

# %%
thraupidae_nemosia = ['Nemosia pileata']
thraupidae_sericossypha = ['Sericossypha albocristata']
thraupidae_parkerthraustes = ['Parkerthraustes humeralis']
thraupidae_catamblyrhynchus = ['Catamblyrhynchus diadema']
thraupidae_chlorophanes = ['Chlorophanes spiza']
thraupidae_iridophanes = ['Iridophanes pulcherrimus']
thraupidae_chrysothlypis = ['Chrysothlypis salmoni', 'Chrysothlypis chrysomelas'] 
thraupidae_heterospingus = [' Heterospingus xanthopygius']
thraupidae_hemithraupis = ['Hemithraupis guira', 'Hemithraupis flavicollis']
thraupidae_conirostrum = ['Conirostrum bicolor', 'Conirostrum speciosum', 'Conirostrum leucogenys', 'Conirostrum binghami', 'Conirostrum sitticolor', 'Conirostrum albifrons',
                        'Conirostrum rufum', 'Conirostrum cinereum']
thraupidae_sicalis = ['Sicalis citrina', 'Sicalis columbiana', 'Sicalis flaveola', 'Sicalis luteola']
thraupidae_catamenia = ['Catamenia analis', 'Catamenia homochroa', 'Catamenia inornata']
thraupidae_geospizopsis = ['Geospizopsis unicolor']
thraupidae_volatinia = ['Volatinia jacarina']
thraupidae_diglossa = ['Diglossa gloriosissima', 'Diglossa lafresnayii', 'Diglossa humeralis', 'Diglossa brunneiventris', 'Diglossa albilatera', 'Diglossa indigotica',
                    'Diglossa sittoides', 'Diglossa glauca', 'Diglossa caerulescens', 'Diglossa cyanea'] 
thraupidae_conothraupis = ['Conothraupis speculigera']
thraupidae_creurgops = ['Creurgops verticalis']
thraupidae_tachyphonus = ['Tachyphonus surinamus', 'Tachyphonus delatrii', 'Tachyphonus rufus', 'Tachyphonus phoenicius']
thraupidae_eucometis = ['Eucometis penicillata']
thraupidae_ramphocelus = ['Ramphocelus nigrogularis', 'Ramphocelus dimidiatus', 'Ramphocelus carbo', 'Ramphocelus flammigerus']
thraupidae_lanio = ['Lanio fulvus']
thraupidae_cyanerpes = ['Cyanerpes nitidus', 'Cyanerpes lucidus', 'Cyanerpes caeruleus', 'Cyanerpes cyaneus']
thraupidae_tersina = ['Tersina viridis'] 
thraupidae_dacnis = ['Dacnis albiventris', 'Dacnis lineata', 'Dacnis flaviventer', 'Dacnis hartlaubi', 'Dacnis venusta', 'Dacnis cayana', 'Dacnis viguieri', 'Dacnis berlepschi']
thraupidae_coryphospingus = ['Coryphospingus pileatus']
thraupidae_rhodospingus = ['Rhodospingus cruentus']
thraupidae_sporophila = ['Sporophila bouvronides', 'Sporophila lineola', 'Sporophila telasco', 'Sporophila castaneiventris', 'Sporophila minuta', 'Sporophila funerea',
                        'Sporophila angolensis', 'Sporophila crassirostris', 'Sporophila corvina', 'Sporophila intermedia', 'Sporophila murallae', 'Sporophila fringilloides',
                        'Sporophila luctuosa', 'Sporophila nigricollis', 'Sporophila caerulescens', 'Sporophila schistacea', 'Sporophila plumbea']

# %%
thraupidae = [thraupidae_nemosia, thraupidae_sericossypha, thraupidae_parkerthraustes, thraupidae_catamblyrhynchus, thraupidae_chlorophanes, thraupidae_iridophanes,
                thraupidae_chrysothlypis, thraupidae_heterospingus, thraupidae_hemithraupis, thraupidae_conirostrum, thraupidae_sicalis, thraupidae_catamenia,
                thraupidae_geospizopsis, thraupidae_volatinia, thraupidae_diglossa, thraupidae_conothraupis, thraupidae_creurgops, thraupidae_tachyphonus,
                thraupidae_eucometis, thraupidae_ramphocelus, thraupidae_lanio, thraupidae_cyanerpes, thraupidae_tersina, thraupidae_dacnis, thraupidae_coryphospingus,
                thraupidae_rhodospingus, thraupidae_sporophila]

# %%
family_dict = {
    # 'Thamnophilidae': thamnophilidae,
    # 'Conopophagidae': conopophagidae,
    # 'Grallaridae': grallaridae,
    # 'Rhinocryptidae': rhinocryptidae,
    # 'Formicariidae': formicariidae,
    # 'Furnariidae': furnariidae,
    # 'Sapayoidae': sapayoidae,
    # 'Tyrannidae': tyrannidae,
    # 'Cotingidae': cotingidae,
    # 'Pipridae': pipridae,
    # 'Tityridae': tityridae,
    # 'Vireonidae': vireonidae, --> no hay
    # 'Corvidae': corvidae,
    # 'Alaudidae': alaudidae,
    # 'Hirundinidae': hirundinidae,
    # 'Troglodytidae': troglodytidae,
    # 'Polioptilidae': polioptilidae,
    'Donacobiidae': donacobiidae,
    'Cinclidae': cinclidae,
    'Bombycillidae': bombycillidae,
    'Turdidae': turdidae,
    'Mimidae': mimidae,
    'Motacillidae': motacillidae,
    'Thraupidae': thraupidae
    
}

# %%
def extract_data(family_dict):
    for family, genus_list in family_dict.items():
        for genus in genus_list:
            for species in genus:
                genus_name = species.split()[0]
                q = Query(name=species)
                q.retrieve_recordings(multiprocess=True, nproc=10, attempts=10, outdir=f"datasets/{family}/{genus_name}/{species}")

# %%
extract_data(family_dict)
# Out:
# query: Donacobius atricapilla
# ... retrieving metadata ...
# ... finished ...
# query: Cinclus leucocephalus
# ... retrieving metadata ...
# ... finished ...
# query: Bombycilla cedrorum
# ... retrieving metadata ...
# ... finished ...
# query: Turdus leucops
# ... retrieving metadata ...
# ... finished ...
# query: Turdus flavipes
# ... retrieving metadata ...
# ... finished ...
# query: Turdus leucomelas
# ... retrieving metadata ...
# ... finished ...
# query: Turdus fumigatus
# ... retrieving metadata ...
# ... finished ...
# query: Turdus hauxwelli
# ... retrieving metadata ...
# ... finished ...
# query: Turdus obsoletus
# ... retrieving metadata ...
# ... finished ...
# query: Turdus grayi
# ... retrieving metadata ...
# ... finished ...
# query: Turdus nudigenis
# ... retrieving metadata ...
# ... finished ...
# query: Turdus nudigenis
# ... retrieving metadata ...
# ... finished ...
# query: Turdus maculirostris
# ... retrieving metadata ...
# ... finished ...
# ...
