# %% [markdown]
# # Notes

# %%
import pandas as pd
import numpy as np
from scipy import stats

# librosa
import librosa
import librosa.display

# %%
import sys
import os

# Obtener la ruta del directorio raíz
root_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# %%
from src.data_engineering import process_features

# %%
familias = os.listdir('songs/')
for familia in familias:
    print(f'Procesando familia: {familia}')
    
    generos_path = f'songs/{familia}/'
    generos = os.listdir(generos_path)
    for genero in generos:
        print(f'\tProcesando género: {genero}')
        
        especies_path = f'{generos_path}{genero}/'
        especies = os.listdir(especies_path)
        for especie in especies:
            print(f'\t\tProcesando especie: {especie}')
            
            name_comun_path = f'{especies_path}{especie}/'
            name_comuns = os.listdir(name_comun_path)
            for name_comun in name_comuns:
                ruta_base = f'{name_comun_path}{name_comun}'
                print(f'\t\t\tRuta base: {ruta_base}')
                
                nombre_archivo = f"./data/{familia}_{genero}_{especie}.csv"
                if not os.path.exists(nombre_archivo):
                    process_features(
                    f"{ruta_base}/",
                    "./data/"
                    f"{familia}_{genero}_{especie}"
                    )
                else:
                    print(f'El archivo {nombre_archivo} ya existe, saltando procesamiento.')
# Out:
# Procesando familia: Alaudidae
# 	Procesando género: Eremophila
# 		Procesando especie: Eremophila alpestris
# 			Ruta base: songs/Alaudidae/Eremophila/Eremophila alpestris/HornedLark
# El archivo ./data/Alaudidae_Eremophila_Eremophila alpestris.csv ya existe, saltando procesamiento.
# Procesando familia: Bombycillidae
# 	Procesando género: Bombycilla
# 		Procesando especie: Bombycilla cedrorum
# 			Ruta base: songs/Bombycillidae/Bombycilla/Bombycilla cedrorum/CedarWaxwing
# El archivo ./data/Bombycillidae_Bombycilla_Bombycilla cedrorum.csv ya existe, saltando procesamiento.
# Procesando familia: Cinclidae
# 	Procesando género: Cinclus
# 		Procesando especie: Cinclus leucocephalus
# 			Ruta base: songs/Cinclidae/Cinclus/Cinclus leucocephalus/White-cappedDipper
# El archivo ./data/Cinclidae_Cinclus_Cinclus leucocephalus.csv ya existe, saltando procesamiento.
# Procesando familia: Conopophagidae
# 	Procesando género: Conopophaga
# 		Procesando especie: Conopophaga aurita
# 			Ruta base: songs/Conopophagidae/Conopophaga/Conopophaga aurita/Chestnut-beltedGnateater
# El archivo ./data/Conopophagidae_Conopophaga_Conopophaga aurita.csv ya existe, saltando procesamiento.
# 		Procesando especie: Conopophaga castaneiceps
# 			Ruta base: songs/Conopophagidae/Conopophaga/Conopophaga castaneiceps/Chestnut-crownedGnateater
# El archivo ./data/Conopophagidae_Conopophaga_Conopophaga castaneiceps.csv ya existe, saltando procesamiento.
# 		Procesando especie: Conopophaga peruviana
# 			Ruta base: songs/Conopophagidae/Conopophaga/Conopophaga peruviana/Ash-throatedGnateater
# El archivo ./data/Conopophagidae_Conopophaga_Conopophaga peruviana.csv ya existe, saltando procesamiento.
# 	Procesando género: Pittasoma
# 		Procesando especie: Pittasoma michleri
# 			Ruta base: songs/Conopophagidae/Pittasoma/Pittasoma michleri/Black-crownedAntpitta
# El archivo ./data/Conopophagidae_Pittasoma_Pittasoma michleri.csv ya existe, saltando procesamiento.
# 		Procesando especie: Pittasoma rufopileatum
# 			Ruta base: songs/Conopophagidae/Pittasoma/Pittasoma rufopileatum/Rufous-crownedAntpitta
# El archivo ./data/Conopophagidae_Pittasoma_Pittasoma rufopileatum.csv ya existe, saltando procesamiento.
# Procesando familia: Corvidae
# 	Procesando género: Cyanocorax
# 		Procesando especie: Cyanocorax affinis
# 			Ruta base: songs/Corvidae/Cyanocorax/Cyanocorax affinis/Black-chestedJay
# El archivo ./data/Corvidae_Cyanocorax_Cyanocorax affinis.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cyanocorax heilprini
# 			Ruta base: songs/Corvidae/Cyanocorax/Cyanocorax heilprini/Azure-napedJay
# El archivo ./data/Corvidae_Cyanocorax_Cyanocorax heilprini.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cyanocorax violaceus
# 			Ruta base: songs/Corvidae/Cyanocorax/Cyanocorax violaceus/ViolaceousJay
# El archivo ./data/Corvidae_Cyanocorax_Cyanocorax violaceus.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cyanocorax yncas
# 			Ruta base: songs/Corvidae/Cyanocorax/Cyanocorax yncas/IncaJay
# El archivo ./data/Corvidae_Cyanocorax_Cyanocorax yncas.csv ya existe, saltando procesamiento.
# 	Procesando género: Cyanolyca
# 		Procesando especie: Cyanolyca armillata
# 			Ruta base: songs/Corvidae/Cyanolyca/Cyanolyca armillata/Black-collaredJay
# El archivo ./data/Corvidae_Cyanolyca_Cyanolyca armillata.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cyanolyca pulchra
# 			Ruta base: songs/Corvidae/Cyanolyca/Cyanolyca pulchra/BeautifulJay
# El archivo ./data/Corvidae_Cyanolyca_Cyanolyca pulchra.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cyanolyca turcosa
# 			Ruta base: songs/Corvidae/Cyanolyca/Cyanolyca turcosa/TurquoiseJay
# El archivo ./data/Corvidae_Cyanolyca_Cyanolyca turcosa.csv ya existe, saltando procesamiento.
# Procesando familia: Cotingidae
# 	Procesando género: Ampelioides
# 		Procesando especie: Ampelioides tschudii
# 			Ruta base: songs/Cotingidae/Ampelioides/Ampelioides tschudii/ScaledFruiteater
# El archivo ./data/Cotingidae_Ampelioides_Ampelioides tschudii.csv ya existe, saltando procesamiento.
# 	Procesando género: Ampelion
# 		Procesando especie: Ampelion rubrocristatus
# 			Ruta base: songs/Cotingidae/Ampelion/Ampelion rubrocristatus/Red-crestedCotinga
# El archivo ./data/Cotingidae_Ampelion_Ampelion rubrocristatus.csv ya existe, saltando procesamiento.
# 		Procesando especie: Ampelion rufaxilla
# 			Ruta base: songs/Cotingidae/Ampelion/Ampelion rufaxilla/Chestnut-crestedCotinga
# El archivo ./data/Cotingidae_Ampelion_Ampelion rufaxilla.csv ya existe, saltando procesamiento.
# 	Procesando género: Carpodectes
# 		Procesando especie: Carpodectes hopkei
# 			Ruta base: songs/Cotingidae/Carpodectes/Carpodectes hopkei/Black-tippedCotinga
# El archivo ./data/Cotingidae_Carpodectes_Carpodectes hopkei.csv ya existe, saltando procesamiento.
# 	Procesando género: Cephalopterus
# 		Procesando especie: Cephalopterus ornatus
# 			Ruta base: songs/Cotingidae/Cephalopterus/Cephalopterus ornatus/AmazonianUmbrellabird
# El archivo ./data/Cotingidae_Cephalopterus_Cephalopterus ornatus.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cephalopterus penduliger
# 			Ruta base: songs/Cotingidae/Cephalopterus/Cephalopterus penduliger/Long-wattledUmbrellabird
# El archivo ./data/Cotingidae_Cephalopterus_Cephalopterus penduliger.csv ya existe, saltando procesamiento.
# 	Procesando género: Cotinga
# 		Procesando especie: Cotinga cayana
# 			Ruta base: songs/Cotingidae/Cotinga/Cotinga cayana/SpangledCotinga
# El archivo ./data/Cotingidae_Cotinga_Cotinga cayana.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cotinga cotinga
# 			Ruta base: songs/Cotingidae/Cotinga/Cotinga cotinga/Purple-breastedCotinga
# El archivo ./data/Cotingidae_Cotinga_Cotinga cotinga.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cotinga maynana
# 			Ruta base: songs/Cotingidae/Cotinga/Cotinga maynana/Plum-throatedCotinga
# El archivo ./data/Cotingidae_Cotinga_Cotinga maynana.csv ya existe, saltando procesamiento.
# 		Procesando especie: Cotinga nattererii
# 			Ruta base: songs/Cotingidae/Cotinga/Cotinga nattererii/BlueCotinga
# El archivo ./data/Cotingidae_Cotinga_Cotinga nattererii.csv ya existe, saltando procesamiento.
# 	Procesando género: Doliornis
# 		Procesando especie: Doliornis remseni
# 			Ruta base: songs/Cotingidae/Doliornis/Doliornis remseni/Chestnut-belliedCotinga
# El archivo ./data/Cotingidae_Doliornis_Doliornis remseni.csv ya existe, saltando procesamiento.
# 	Procesando género: Gymnoderus
# 		Procesando especie: Gymnoderus foetidus
# 			Ruta base: songs/Cotingidae/Gymnoderus/Gymnoderus foetidus/Bare-neckedFruitcrow
# El archivo ./data/Cotingidae_Gymnoderus_Gymnoderus foetidus.csv ya existe, saltando procesamiento.
# 	Procesando género: Haematoderus
# 		Procesando especie: Haematoderus militaris
# 			Ruta base: songs/Cotingidae/Haematoderus/Haematoderus militaris/CrimsonFruitcrow
# El archivo ./data/Cotingidae_Haematoderus_Haematoderus militaris.csv ya existe, saltando procesamiento.
# 	Procesando género: Lipaugus
# 		Procesando especie: Lipaugus fuscocinereus
# 			Ruta base: songs/Cotingidae/Lipaugus/Lipaugus fuscocinereus/DuskyPiha
# El archivo ./data/Cotingidae_Lipaugus_Lipaugus fuscocinereus.csv ya existe, saltando procesamiento.
# 		Procesando especie: Lipaugus unirufus
# 			Ruta base: songs/Cotingidae/Lipaugus/Lipaugus unirufus/RufousPiha
# El archivo ./data/Cotingidae_Lipaugus_Lipaugus unirufus.csv ya existe, saltando procesamiento.
# 		Procesando especie: Lipaugus vociferans
# 			Ruta base: songs/Cotingidae/Lipaugus/Lipaugus vociferans/ScreamingPiha
# El archivo ./data/Cotingidae_Lipaugus_Lipaugus vociferans.csv ya existe, saltando procesamiento.
# 		Procesando especie: Lipaugus weberi
# 			Ruta base: songs/Cotingidae/Lipaugus/Lipaugus weberi/Chestnut-cappedPiha
# El archivo ./data/Cotingidae_Lipaugus_Lipaugus weberi.csv ya existe, saltando procesamiento.
# 	Procesando género: Perissocephalus
# 		Procesando especie: Perissocephalus tricolor
# 			Ruta base: songs/Cotingidae/Perissocephalus/Perissocephalus tricolor/Capuchinbird
# El archivo ./data/Cotingidae_Perissocephalus_Perissocephalus tricolor.csv ya existe, saltando procesamiento.
# 	Procesando género: Phoenicircus
# 		Procesando especie: Phoenicircus nigricollis
# 			Ruta base: songs/Cotingidae/Phoenicircus/Phoenicircus nigricollis/Black-neckedRedCotinga
# 	Procesando género: Pipreola
# 		Procesando especie: Pipreola arcuata
# 			Ruta base: songs/Cotingidae/Pipreola/Pipreola arcuata/BarredFruiteater
# 		Procesando especie: Pipreola aureopectus
# 			Ruta base: songs/Cotingidae/Pipreola/Pipreola aureopectus/Golden-breastedFruiteater
# 		Procesando especie: Pipreola jucunda
# 			Ruta base: songs/Cotingidae/Pipreola/Pipreola jucunda/Orange-breastedFruiteater
# 		Procesando especie: Pipreola lubomirskii
# 			Ruta base: songs/Cotingidae/Pipreola/Pipreola lubomirskii/Black-chestedFruiteater
# 		Procesando especie: Pipreola riefferii
# 			Ruta base: songs/Cotingidae/Pipreola/Pipreola riefferii/Green-and-blackFruiteater

# %%
# process_features(
#     "songs/Alaudidae/Eremophila/Eremophila alpestris/HornedLark/",
#     "./data/"
#     "ElegantWoodcreeper"
# )
